# %% [markdown]
# <a href="https://colab.research.google.com/github/Erickson117/edd_1358_2021/blob/master/Tarea_3_Reyes_Garcia_Erick_Jesus_1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Alumno: Reyes Garcia Erick Jesus  Grupo: 1358 
class Array2D:

    def __init__(self,rows, cols, value):
        self.__cols = cols
        self.__rows = rows
        self.__array=[[value for x in range(self.__cols)] for y in range(self.__rows)]
        
        

        
    
    def to_string(self):
        [print("---",end="") for x in range(self.__cols)]
        print("")
        for ren in self.__array:
            print(ren)
        [print("---",end="") for x in range(self.__cols)]
        print("")

    def get_num_rows(self):
        return self.__rows

    def get_num_cols(self):
        return self.__cols

    def get_item(self,row,col):
        return self.__array[row][col]

    def set_item( self , row , col , valor ):
        self.__array[row][col]=valor
    
    def get_generaciones(self):
      return self.__generaciones
    
    def get_poblacion(self):
      return self.__poblacion

    def clearing(self, valor=0):
        for ren in range(self.__rows):
            for col in range(self.__cols):
                self.__array[ren][col]=valor
    


# Metodos

# %%
class JuegoDeLaVida:
   
 
  def __init__(self,arreglo,generaciones,poblacion):
     self.__CELULA_VIVA = 1
     self.__celula_muerta = 0
     self.__columnas = arreglo.get_num_cols()
     self.__renglones = arreglo.get_num_rows()
     self.grid = Array2D(self.__renglones,self.__renglones,0)
     self.__generaciones = generaciones  
     self.__poblacion = poblacion
     for l in range(len(poblacion)):
       x = poblacion[l][0]
       y = poblacion[l][1]
       self.grid.set_item(x,y,self.__CELULA_VIVA)
  def configura_generacion(self,nueva_poblacion):
        self.grid.clearing()
        for celula in nueva_poblacion:
            self.grid.set_item(celula[0],celula[1],self.__CELULA_VIVA)
  def imprime_grid(self):
        for r in range(self.__renglones):
            for c in range(self.__columnas):
                if self.grid.get_item(r,c) == 0:
                    print("░░",end="")
                else:
                    print("▓▓",end="")
            print("")
  def get_num_rows(self):
        return self.__renglones
  def get_num_cols(self):
        return self.__columnas
  def set_celula_muerta(self, renglon, columna):
    self.grid.set_item(renglon,columna,0)

  def get_is_live(self,renglon,comuna):
    return self.get_item(renglon,columna) == 1

  def get_is_death(self,renglon,columna):
    return self.get_item(renglon,columna) == 0

  def set_celula_viva(self,renglon,columna):
    self.grid.set_item(renglon,columna,1)

  def get_vecinos_vivos(self,renglon,columna):
    no_vecinos_vivos = 0
    abajo = renglon+1
    isquierda = columna-1
    arriba = renglon-1
    derecha = columna+1
    
    if abajo < self.grid.get_num_rows():  #abajo
      if self.grid.get_item( abajo ,columna) == 1:
        no_vecinos_vivos += 1
    if  abajo < self.grid.get_num_rows() and derecha < self.grid.get_num_cols(): #abajo a la derecha
      if self.grid.get_item(abajo,derecha) == 1:
        no_vecinos_vivos += 1
    if derecha < self.grid.get_num_cols() : #derecha
      if self.grid.get_item(renglon,derecha) == 1:
        no_vecinos_vivos += 1
    if arriba >= 0 and derecha < self.grid.get_num_cols(): #arriba a la derecha
       if self.grid.get_item(arriba,derecha) == 1:
         no_vecinos_vivos += 1
    if arriba >= 0 : #arriba
       if self.grid.get_item(arriba,columna) == 1:
         no_vecinos_vivos += 1
    if arriba >= 0 and isquierda >= 0: #arriba a la isquierda
      if self.grid.get_item(arriba,isquierda) == 1:
        no_vecinos_vivos += 1
    if abajo < self.grid.get_num_rows() and isquierda >= 0: #abajo a la isquierda
      if self.grid.get_item(abajo,isquierda) == 1:
        no_vecinos_vivos += 1 
    if isquierda >= 0:
      if self.grid.get_item(renglon, isquierda) == 1:
        no_vecinos_vivos += 1
        
        
          
    return no_vecinos_vivos     
          
  def evolucionar(self):
    arreglo = []
    self.imprime_grid()
    for g in range(self.__generaciones):
      for r in range(self.grid.get_num_rows()):
        for c in range(self.grid.get_num_cols()):
          if self.grid.get_item(r,c) == 1:
            if self.get_vecinos_vivos(r,c) > 1 and self.get_vecinos_vivos(r,c) < 4:
              arreglo.append((r,c))
          if self.grid.get_item(r,c) == 0:
            if self.get_vecinos_vivos(r,c) == 3:
              arreglo.append((r,c))
      self.configura_generacion(arreglo)
      arreglo.clear()
      print("--------------")
      self.imprime_grid()
          
      
              
          
uwu = Array2D(7,7,1)
arreglotuplas = [(1,2), (2,1), (2,2), (2,3)]
ejemplo1 = JuegoDeLaVida(uwu,8,arreglotuplas)
ejemplo1.evolucionar()
# Out:
# ░░░░░░░░░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# --------------
# ░░░░░░░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# --------------
# ░░░░▓▓░░░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# --------------
# ░░░░▓▓░░░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# --------------
# ░░░░░░░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# --------------
# ░░░░▓▓░░░░░░░░
# ░░▓▓░░▓▓░░░░░░
# ▓▓░░░░░░▓▓░░░░
# ░░▓▓░░▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# --------------
# ░░░░▓▓░░░░░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ▓▓▓▓░░▓▓▓▓░░░░
# ░░▓▓▓▓▓▓░░░░░░
# ░░░░▓▓░░░░░░░░
# ░░░░░░░░░░░░░░
# ░░░░░░░░░░░░░░
# --------------
# ░░▓▓▓▓▓▓░░░░░░
# ▓▓░░░░░░▓▓░░░░
# ...
