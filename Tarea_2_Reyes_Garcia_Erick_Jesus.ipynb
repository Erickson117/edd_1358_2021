# %% [markdown]
# <a href="https://colab.research.google.com/github/Erickson117/edd_1358_2021/blob/master/Tarea_2_Reyes_Garcia_Erick_Jesus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Array
"""

class Array:
  def __init__(self,tam):
    self.__datos = [0 for x in range(tam) ]

  def get_item(self, index):
    dato = 0
    if index >= 0 and index < len(self.__datos):
      dato = self.__datos[index]
    else:
      print("error en el indice")

    return dato
  
  def set_item(self, index , dato):
     if index >= 0 and index < len(self.__datos):
       self.__datos[index] = dato
     else:
       print("error en el indice")
  
  def get_leght(self):
    tamano = len(self.__datos)
    return tamano
  def clear(self,dato):
    self.__datos = [ dato for x in range(self.__tam)]
  def __iter__(self):
    return _getIterador(self.__datos)



class _getIterador:
  def __init__(self,arreglo):
    self.__arreglo = arreglo
    self.__indice_actual = 0

  def __iter__(self):
    return self
  def __next__(self):
    if self.__indice_actual < len(self.__arreglo):
      dato = self.__arreglo[self.__indice_actual]
      self.__indice_actual += 1
      return dato
    else:
      raise StopIteration

# %%
class Empleado:
  self.__num_trabajador = num
  self.__nombres = nom
  self.__paterno = pat
  self.__materno = mat
  self.__horas_extra = hoe
  self.sueldo = sue

# %%
"""
ADT sueldos --> encapsula datos de nomina
cargar_datos(ruta de archivo)
calcular_sueldos()
reportar_mayor_antiguedad()
reportar_menor_antiguedad()

"""
class Sueldos:
  def __init__(self):
    self.__data = None
    

  def cargar_datos(self, ruta_archivo):
    ## se abre el archivo 
    archivo = open(ruta_archivo, "rt",encoding= 'latin1')
    ##se define una lista "lineas"
    lineas = archivo.readlines()
    ## se cierra el archivo
    archivo.close()
    ## se crea  un arreglo de strings procedentes de cada linea
    self.__data = Array(len(lineas)-1)
    ## se separan los str para poder manipularlos
    lista1 = lineas[1]
    lista2 = lineas[2]
    lista3 = lineas[3]
    lista4 = lineas[4]
    lista5 = lineas[5]
    lista6 = lineas[6]
    lista7 = lineas[7]
    lista8 = lineas[8]
    lista9 = lineas[9]
    lista10 = lineas[10]
    lista11 = lineas[11]
    lista12 = lineas[12]
    lista13 = lineas[13]
    lista14 = lineas[14]
    ## se manipulan los str  de manera que las listas separen sus elementos
    lista1 = ''.join(lista1)
    lista1 = lista1.rstrip('\n')
    lista01 = lista1.split(",")

    
    lista2 = ''.join(lista2)
    lista2 = lista2.rstrip('\n')
    lista02 = lista2.split(",")

    lista3 = ''.join(lista3)
    lista3 = lista3.rstrip('\n')
    lista03 = lista3.split(",")
    
    lista4 = ''.join(lista4)
    lista4 = lista4.rstrip('\n')
    lista04 = lista4.split(",")
    
    lista5 = ''.join(lista5)
    lista5 = lista5.rstrip('\n')
    lista05 = lista5.split(",")
    
    lista6 = ''.join(lista6)
    lista6 = lista6.rstrip('\n')
    lista06 = lista6.split(",")

    lista7 = ''.join(lista7)
    lista7 = lista7.rstrip('\n')
    lista07 = lista7.split(",") 
    
    lista8 = ''.join(lista8)
    lista8 = lista8.rstrip('\n')
    lista08 = lista8.split(",")

    lista9 = ''.join(lista9)
    lista9 = lista9.rstrip('\n')
    lista09 = lista9.split(",")

    lista10 = ''.join(lista10)
    lista10 = lista10.rstrip('\n')
    lista010 = lista10.split(",")

    lista11 = ''.join(lista11)
    lista11 = lista11.rstrip('\n')
    lista011 = lista11.split(",")

    lista12 = ''.join(lista12)
    lista12 = lista12.rstrip('\n')
    lista012 = lista12.split(",")

    lista13 = ''.join(lista13)
    lista13 = lista13.rstrip('\n')
    lista013 = lista13.split(",")

    lista14 = ''.join(lista14)
    lista14 = lista14.rstrip('\n')
    lista014 = lista14.split(",") 
    #se crea y se regresa una lista multidimencional a partir de las listas que use para manipularlas

    lista = [lista01,lista02,lista03,lista04,lista05,lista06,lista07,lista08,lista09,lista010,lista011,lista012,lista013,lista014]
    
    return lista
  
  def calcular_sueldos(self,arreglo):
    ## recibe la lista que se genero apartir de la funcion cargar datos
    self.arreglo = arreglo
    ## itero para generar el dinero generado a traves de un for 
    for i in range(14):
      ## obtiene el sueldo base y lo castea a un valor entero
      sueldo_base = int(self.arreglo[i][5])
      ## obtiene el sueldo generado por las horas extra y lo castea a un entero
      sueldo_horasextra = int(self.arreglo[i][4]) * 246.5
      ##obtiene el sueldo generado por la antiguedad y lo castea a un entero
      sueldo_antiguedad = (2020 - int(self.arreglo[i][6]) )* .03
      ## suma los sueldos anteriores para obtener el sueldo total
      sueldo_total = sueldo_base + sueldo_horasextra + sueldo_antiguedad
      print(f"Sueldo total de :{self.arreglo[i][1]} {self.arreglo[i][2]} {self.arreglo[i][3]} es de: {sueldo_total} $")

  def reportar_menor_antiguedad(self, arreglo):
    
    self.arreglo = arreglo
    ## a traves de if anidados la computadora compara los años de ingreso de los trabajadores y apartir de ahi decide cual es el de menor antiguedad
    for i in range(14):
      if int(self.arreglo[i][6]) >= int(self.arreglo[0][6]):
        if int(self.arreglo[i][6]) >= int(self.arreglo[1][6]):
          if int(self.arreglo[i][6]) >= int(self.arreglo[2][6]):
            if int(self.arreglo[i][6]) >= int(self.arreglo[3][6]):
              if int(self.arreglo[i][6]) >= int(self.arreglo[4][6]):
                if int(self.arreglo[i][6]) >= int(self.arreglo[5][6]):
                  if int(self.arreglo[i][6]) >= int(self.arreglo[6][6]):
                    if int(self.arreglo[i][6]) >= int(self.arreglo[7][6]):
                      if int(self.arreglo[i][6]) >= int(self.arreglo[8][6]):
                        if int(self.arreglo[i][6]) >= int(self.arreglo[9][6]):
                          if int(self.arreglo[i][6]) >= int(self.arreglo[10][6]):
                           if int(self.arreglo[i][6]) >= int(self.arreglo[11][6]):
                             if int(self.arreglo[i][6]) >= int(self.arreglo[12][6]):
                               if int(self.arreglo[i][6]) >= int(self.arreglo[13][6]):
                                 ##aqui ya ha tomado su decision por lo que imprime los datos del trabajador de menor antiguedad 
                                 print(f"El empleado {self.arreglo[i][1]} {self.arreglo[i][2]} {self.arreglo[i][3]} es el empleado con menor antiguedad pues entro en el: {self.arreglo[i][6]}")
                    
  def reportar_mayor_antiguedad(self, arreglo):
    
    self.arreglo = arreglo
    ## se hace la misma iteracion pero se modifica el operador logico para obtener el empleado de mayor antiguedad
    for i in range(14):
      if int(self.arreglo[i][6]) <= int(self.arreglo[0][6]):
        if int(self.arreglo[i][6]) <= int(self.arreglo[1][6]):
          if int(self.arreglo[i][6]) <= int(self.arreglo[2][6]):
            if int(self.arreglo[i][6]) <= int(self.arreglo[3][6]):
              if int(self.arreglo[i][6]) <= int(self.arreglo[4][6]):
                if int(self.arreglo[i][6]) <= int(self.arreglo[5][6]):
                  if int(self.arreglo[i][6]) <= int(self.arreglo[6][6]):
                    if int(self.arreglo[i][6]) <= int(self.arreglo[7][6]):
                      if int(self.arreglo[i][6]) <= int(self.arreglo[8][6]):
                        if int(self.arreglo[i][6]) <= int(self.arreglo[9][6]):
                          if int(self.arreglo[i][6]) <= int(self.arreglo[10][6]):
                           if int(self.arreglo[i][6]) <= int(self.arreglo[11][6]):
                             if int(self.arreglo[i][6]) <= int(self.arreglo[12][6]):
                               if int(self.arreglo[i][6]) <= int(self.arreglo[13][6]):
                                 #se toma la decision y se imprime el o los nombres de los trabajadores que cumplan con esa condicion 
                                 print(f"El empleado {self.arreglo[i][1]} {self.arreglo[i][2]} {self.arreglo[i][3]} es el empleado con mayor antiguedad pues entro en el: {self.arreglo[i][6]}")                 


  ##def __antiguedad(self)

ejemplo1 = Sueldos()
ejemplo1.cargar_datos('junio.dat')
ejemplo1.calcular_sueldos(ejemplo1.cargar_datos('junio.dat'))
ejemplo1.reportar_menor_antiguedad(ejemplo1.cargar_datos('junio.dat'))
ejemplo1.reportar_mayor_antiguedad(ejemplo1.cargar_datos('junio.dat'))
# Out:
# Sueldo total de :CARLOS PEREZ CASTILLO es de: 9850.09 $
# Sueldo total de :ANGEL GOMEZ GARRIDO es de: 10096.5 $
# Sueldo total de :JESUS MARTIN SANTOS es de: 10343.12 $
# Sueldo total de :DAVID JIMENEZ LOZANO es de: 10343.09 $
# Sueldo total de :PEDRO RUIZ GUERRERO es de: 10343.09 $
# Sueldo total de :DANIEL HERNANDEZ CANO es de: 10589.56 $
# Sueldo total de :ALEJANDRO DIAZ PRIETO es de: 10343.06 $
# Sueldo total de :MARIA MORENO MENDEZ es de: 10096.56 $
# Sueldo total de :ALBERTO MUï¿½OZ CRUZ es de: 10096.59 $
# Sueldo total de :RAFAEL ALVAREZ FLORES es de: 10343.09 $
# Sueldo total de :FERNANDO ROMERO HERRERA es de: 10836.03 $
# Sueldo total de :PABLO ALONSO GALLEGO es de: 10096.53 $
# Sueldo total de :JORGE GUTIERREZ MARQUEZ es de: 10343.0 $
# Sueldo total de :RAMON NAVARRO LEON es de: 10096.62 $
# El empleado ANGEL GOMEZ GARRIDO es el empleado con menor antiguedad pues entro en el: 2020
# ...
