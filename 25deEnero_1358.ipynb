# %% [markdown]
# <a href="https://colab.research.google.com/github/Erickson117/edd_1358_2021/blob/master/25deEnero_1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class NodoArbol:
  def __init__(self, value, left = None, right = None):
    self.data = value
    self.left = left
    self.right = right

# %%
class ArbolBinarioBusqueda:
  def __init__( self ):
    self.__root = None

  def insert( self , value):
    if self.__root == None:
      self.__root = NodoArbol(value)
    else:
      self.__insert__( self.__root , value)


  def __insert__( self, nodo, value): #recursividad
    if nodo.data == value:
      print("El nodo ya existe, no se inserta: ", value)
    elif value < nodo.data:
      #ir a la izq
      if nodo.left == None:
        nodo.left = NodoArbol(value)
      else:
        self.__insert__( nodo.left, value)
      
    else:
      #ir a la der
      if nodo.right == None:
        nodo.right = NodoArbol(value)
      else:
        self.__insert__(nodo.right,value)
  
  def transversal( self , format="" ):#in, pos , pre
    if format == "in":
      #print("recorrido in orden")
      self.__recorrido_in(self.__root)
      print("recorrido in orden")
    elif format == "pre":
      #print("recorrido pre orden")
      self.__recorrido_pre(self.__root)
      print("recorrido pre orden")
    elif format == "pos":
      #print("recorrido pos orden")
      self.__recorrido_pos(self.__root)
      print("recorrido pos orden")
      
    else:
      print("invalido")

  def __recorrido_in( self , nodo ):
    if nodo == None:
      #print("caso base")
      pass
    else: 
      self.__recorrido_in( nodo.left )
      print(nodo.data , end="," )
      self.__recorrido_in( nodo.right )
  
  def __recorrido_pre( self , nodo ):
    if nodo == None:
      #print("caso base")
      pass
    else: 
      print(nodo.data , end="," )
      self.__recorrido_pre( nodo.left )
      self.__recorrido_pre( nodo.right )
      
  
  def __recorrido_pos( self , nodo ):
    if nodo == None:
      #print("caso base")
      pass
    else: 
      self.__recorrido_pos( nodo.left )
      self.__recorrido_pos( nodo.right )
      print(nodo.data , end="," )
      
  def search(self, value):
    if self.__root == None:
      print("Arbol vacio")
    else:
      return self.__search(self.__root , value)

  def __search(self,nodo):
    if nodo == None:
      return None

    elif nodo.data == value:
      return nodo

    elif value < nodo.data:
      print("ir a la izquierda")
      return self.__search(nodo.left, value)
    else:
      print("ir a la derecha")
      self.__search(nodo.right, value)
  
  def remove(self, value):
    if self.__root == None:
      print("Arbol vacio")
    else:
      self.__remove(None,None,self.__root, value)
    

  def __remove(self, padre_hi, padre_hd, actual, value):
    if actual == None:
      print("caso base")
      return None
    elif actual.data == value:
      print("\n Encontrado", actual.data)
      #caso 1: nodo hoja
      if actual.left == None and actual.right == None:
        if padre_hi != None:
          padre_hi.left = None
        else:
          padre_hd.right = None
      #caso 2: tiene un hijo
      elif (actual.left != None and actual.right == None) or (actual.left == None and actual.right != None):
        if actual.left != None:
          aux = actual.left
          actual.left = None
          actual = aux         
        else:
          aux = actual.right
          actual.right = None
          actual = aux 
      #caso 3: tiene 2 hijos

    elif value < actual.data:
      self.__remove(actual, None, actual.left, value)
    else:
      self.__remove(actual, None, actual.right, value)

# %%
abb = ArbolBinarioBusqueda()
abb.insert( 50 )
abb.insert( 30 )
abb.insert( 60 )
abb.insert( 35 )
abb.insert( 89 )
abb.insert( 55 )
abb.insert( 1 )
abb.insert( 33 )
abb.insert( 1 )
abb.insert( 80 )
abb.insert( 100 )
abb.insert( 57 )
abb.transversal("in")
abb.transversal("pre")
abb.transversal("pos")

abb.remove(55)

abb.transversal("in")
# Out:
# El nodo ya existe, no se inserta:  1
# 1,30,33,35,50,55,57,60,80,89,100,recorrido in orden
# 50,30,1,35,33,60,55,57,89,80,100,recorrido pre orden
# 1,33,35,30,57,55,80,100,89,60,50,recorrido pos orden
#
#  Encontrado 55
# 1,30,33,35,50,55,60,80,89,100,recorrido in orden
